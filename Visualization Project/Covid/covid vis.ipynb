# %%
import numpy as np
import pandas as pd

# %%
import plotly.graph_objects as go

# %%
import plotly.express as px

# %%
data=pd.read_csv("covid_19_data.csv")

# %%
data.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
data=data.rename(columns={"ObservationDate":"Date","Country/Region":"Country"})

# %%
data_1=data.groupby(['Country','Date']).sum().sort_values("Date",ascending=False).reset_index().copy()
data_1=data_1.drop_duplicates(subset=['Country'])

# %%
data_1
# Out:
#                   Country        Date     SNo  Confirmed   Deaths  Recovered
# 0                      US  04/16/2020  910756   667801.0  32916.0    54703.0
# 1                 Ecuador  04/16/2020   15497     8225.0    403.0      838.0
# 2           Liechtenstein  04/16/2020   15545       79.0      1.0       55.0
# 3                   Egypt  04/16/2020   15498     2673.0    196.0      596.0
# 4             El Salvador  04/16/2020   15499      164.0      6.0       33.0
# ...                   ...         ...     ...        ...      ...        ...
# 6555            Palestine  03/09/2020    4322       22.0      0.0        0.0
# 6601           St. Martin  03/09/2020    4412        2.0      0.0        0.0
# 6723  Republic of Ireland  03/08/2020    4067       21.0      0.0        0.0
# 7399           Azerbaijan  02/28/2020    2664        1.0      0.0        0.0
# 7430        North Ireland  02/28/2020    2685        1.0      0.0        0.0
#
# [220 rows x 6 columns]

# %%
fig_1=go.Figure(data=go.Choropleth(
    z=data_1['Confirmed'],
    locationmode='country names',
    locations=data_1['Country'],
    colorscale="Reds"
)
)
fig_1

# %%
fig_2=go.Figure(data=go.Choropleth(
    z=data_1['Deaths'],
    locationmode='country names',
    locations=data_1['Country'],
    colorscale="blackbody"
)
)
fig_2

# %%
fig_3=go.Figure(data=go.Choropleth(
    z=data_1['Recovered'],
    locationmode='country names',
    locations=data_1['Country'],
    colorscale="greens"
)
)
fig_3

# %%
data_3=data.groupby(['Date','Country']).sum().reset_index()

# %%
data_3
# Out:
#             Date             Country    SNo  Confirmed  Deaths  Recovered
# 0     01/22/2020           Hong Kong     13        0.0     0.0        0.0
# 1     01/22/2020               Japan     36        2.0     0.0        0.0
# 2     01/22/2020               Macau     21        1.0     0.0        0.0
# 3     01/22/2020      Mainland China    535      547.0    17.0       28.0
# 4     01/22/2020         South Korea     38        1.0     0.0        0.0
# ...          ...                 ...    ...        ...     ...        ...
# 8478  04/16/2020  West Bank and Gaza  15626      374.0     2.0       63.0
# 8479  04/16/2020      Western Sahara  15627        6.0     0.0        0.0
# 8480  04/16/2020               Yemen  15628        1.0     0.0        0.0
# 8481  04/16/2020              Zambia  15629       48.0     2.0       30.0
# 8482  04/16/2020            Zimbabwe  15630       23.0     3.0        1.0
#
# [8483 rows x 6 columns]

# %%
fig_11=px.choropleth(
    data_3,
    locations='Country',
    locationmode="country names",
    color="Confirmed", 
    hover_name="Country", 
    animation_frame="Date"
)
fig_11.update_layout(
    title_text = 'Global Spread of Coronavirus',
    title_x = 0.5,
    geo=dict(
        showframe = False,
        showcoastlines = False,
    ))
fig_11.show()

# %%
fig_12=px.bar(
    data_3,
    x="Country",
    y="Confirmed",
    animation_frame="Date"
)
fig_12.show()

# %%
data_4=data.loc[data.Country=="India"].copy()

# %%
data_4
# Out:
#          SNo        Date Province/State Country          Last Update  \
# 430      431  01/30/2020            NaN   India        1/30/20 16:00
# 491      492  01/31/2020            NaN   India      1/31/2020 23:59
# 547      548  02/01/2020            NaN   India       1/31/2020 8:15
# 607      608  02/02/2020            NaN   India  2020-02-02T06:03:08
# 672      673  02/03/2020            NaN   India  2020-02-03T21:43:02
# ...      ...         ...            ...     ...                  ...
# 14243  14244  04/12/2020            NaN   India  2020-04-12 23:25:00
# 14563  14564  04/13/2020            NaN   India  2020-04-13 23:15:42
# 14883  14884  04/14/2020            NaN   India  2020-04-14 23:41:11
# 15203  15204  04/15/2020            NaN   India  2020-04-15 23:04:26
# 15523  15524  04/16/2020            NaN   India  2020-04-16 23:38:19
#
#        Confirmed  Deaths  Recovered
# 430          1.0     0.0        0.0
# 491          1.0     0.0        0.0
# ...

# %%
data_4.describe()
# Out:
#                 SNo     Confirmed      Deaths    Recovered
# count     78.000000     78.000000   78.000000    78.000000
# mean    5760.551282   1535.730769   48.358974   158.179487
# std     4632.808143   3187.280434  106.751194   367.258384
# min      431.000000      1.000000    0.000000     0.000000
# 25%     1782.750000      3.000000    0.000000     3.000000
# 50%     4180.500000     41.000000    0.000000     3.000000
# 75%     9418.250000    962.000000   23.000000    81.250000
# max    15524.000000  13430.000000  448.000000  1768.000000

# %%
fig_15=px.line(
    data_4,
    x="Date",
    y="Confirmed"
)

# %%
fig_15

# %%
data_5=pd.DataFrame(data_4[data_4['Confirmed']>10])

# %%
data_5.describe()
# Out:
#                 SNo     Confirmed      Deaths    Recovered
# count     44.000000     44.000000   44.000000    44.000000
# mean    8949.886364   2720.181818   85.727273   279.250000
# std     3750.899242   3859.784928  130.875827   455.099842
# min     3289.000000     28.000000    0.000000     3.000000
# 25%     5638.000000    110.250000    2.000000    10.750000
# 50%     8730.000000    692.000000   16.000000    44.000000
# 75%    12082.750000   3885.500000  108.250000   265.500000
# max    15524.000000  13430.000000  448.000000  1768.000000

# %%
data_5
# Out:
#          SNo        Date Province/State Country          Last Update  \
# 3288    3289  03/04/2020            NaN   India  2020-03-04T12:33:03
# 3451    3452  03/05/2020            NaN   India  2020-03-05T13:53:03
# 3624    3625  03/06/2020            NaN   India  2020-03-06T13:03:12
# 3825    3826  03/07/2020            NaN   India  2020-03-07T18:13:27
# 4051    4052  03/08/2020            NaN   India  2020-03-08T09:23:05
# 4308    4309  03/09/2020            NaN   India  2020-03-09T09:13:17
# 4573    4574  03/10/2020            NaN   India  2020-03-10T10:13:28
# 4781    4782  03/11/2020            NaN   India  2020-03-11T22:13:12
# 4996    4997  03/12/2020            NaN   India  2020-03-12T08:33:13
# 5277    5278  03/13/2020            NaN   India  2020-03-11T20:00:00
# 5451    5452  03/14/2020            NaN   India  2020-03-14T20:33:03
# 5699    5700  03/15/2020            NaN   India  2020-03-15T18:20:18
# 5967    5968  03/16/2020            NaN   India  2020-03-16T14:38:45
# ...

# %%
fig_31=px.line(
    data_5,
    x="Date",
    y="Confirmed"
)

# %%
fig_31.show()

# %%
px.bar(
    data_1[(data_1['Confirmed']>100)].sort_values("Confirmed",ascending=False),
    x='Country',
    y='Confirmed'
)

# %%
px.bar(
    data_1[(data_1['Deaths']>100)].sort_values("Deaths",ascending=False),
    x='Country',
    y='Deaths'
)
